# %%
from osgeo import gdal
import matplotlib.pyplot as plt
from pyrsimg import readTiff

# %% [markdown]
# 1. D3C1215

# %%
path = 'data/KH-9/D3C1215-100216A012/D3C1215-100216A012_a.tif'
img = gdal.Open(path).ReadAsArray()
plt.imshow(img)

# %%
path = 'data/KH-9/D3C1215-100216A012/D3C1215-100216A012.tif'
img = gdal.Open(path).ReadAsArray()
plt.imshow(img)

# %%
path = 'data/KH-9/D3C1215-100216F011/D3C1215-100216F011.tif'
img = gdal.Open(path).ReadAsArray()
plt.imshow(img)

# %%
path = 'data/KH-9/D3C1215-100216F011/for_down025.tif'
img = gdal.Open(path).ReadAsArray()
plt.imshow(img)

# %%
path = 'data/dem/SRTMGL1Ellip_kh9.tif'
dem = readTiff(path)
plt.imshow(dem.array, vmax=7000, vmin=0, extent=dem.geoextent)
dem.geoextent
# Out:
# (94.00180555559189, 96.27069444448108, 30.3420833333294, 30.80319444444057)

# %%
path = 'data/KH-9/D3C1215-100216F011/for_down025_proj.tif'
# img = gdal.Open(path).ReadAsArray()
img = readTiff(path)
plt.imshow(img.array, vmax=500, vmin=0, extent=img.geoextent)
plt.xlim(94.00180555559189, 96.27069444448108)
plt.ylim(30.3420833333294, 30.80319444444057)
# Out:
# (30.3420833333294, 30.80319444444057)

# %%
path = 'data/KH-9/D3C1215-100216A012/aft_down025_proj.tif'
img = readTiff(path)
plt.imshow(img.array, vmax=500, vmin=0, extent=img.geoextent)
plt.xlim(94.00180555559189, 96.27069444448108)
plt.ylim(30.3420833333294, 30.80319444444057)
# Out:
# (30.3420833333294, 30.80319444444057)

# %% [markdown]
# 2. D3C1217

# %%
path = 'data/KH-9/D3C1217-200742A004/D3C1217-200742A004_a.tif'
img = gdal.Open(path).ReadAsArray()
plt.imshow(img)

# %%
img.shape
# Out:
# (24594, 117848)

# %%
path = 'data/KH-9/D3C1217-200742A004/D3C1217-200742A004.tif'
img = gdal.Open(path).ReadAsArray()
fig, ax = plt.subplots(1,1,figsize=(10,4))
ax.imshow(img)
ax.scatter(1300, 1200, s=3, color='red')
ax.scatter(116748, 1200, s=3, color='red')
ax.scatter(116800, 22800, s=3, color='red')
ax.scatter(1300, 22900, s=3, color='red')

# %%
path = 'data/KH-9/D3C1217-200742A004/aft.tif'
img = gdal.Open(path).ReadAsArray()
fig, ax = plt.subplots(1,1,figsize=(10,4))
ax.imshow(img)
# Out:
# (24482, 126983)

# %%
path = 'data/KH-9/D3C1217-200742F003/D3C1217-200742F003.tif'
img = gdal.Open(path).ReadAsArray()
fig, ax = plt.subplots(1,1, figsize=(10,4))
plt.imshow(img)
ax.scatter(4300, 4000, s=3, color='red')
ax.scatter(123800, 1500, s=3, color='red')
ax.scatter(123800, 23100, s=3, color='red')
ax.scatter(4900, 24400, s=3, color='red')

# %%
path = 'data/KH-9/D3C1217-200742F003/for_down01.tif'
img = gdal.Open(path).ReadAsArray()
fig, ax = plt.subplots(1,1, figsize=(10,4))
plt.imshow(img)

# %%
path = 'data/KH-9/D3C1217-200742F003/for_proj.tif'
img = readTiff(path)
fig, ax = plt.subplots(1,1, figsize=(10,4))
plt.imshow(img.array, vmax=500, vmin=0, extent=img.geoextent)

# %%
path = 'data/KH-9/D3C1217-200742A004/aft_down01.tif'
img = gdal.Open(path).ReadAsArray()
fig, ax = plt.subplots(1,1, figsize=(10,4))
plt.imshow(img)

# %%
path = 'data/KH-9/D3C1217-200742A004/aft_proj.tif'
img = readTiff(path)
fig, ax = plt.subplots(1,1, figsize=(10,4))
plt.imshow(img.array, vmax=500, vmin=0, extent=img.geoextent)

# %%
path = 'data/KH-9/stereo_init_d3c1217/run-DEM.tif'
dem = readTiff(path)
# img = gdal.Open(path).ReadAsArray()
fig, ax = plt.subplots(1,1, figsize=(10,4))
plt.imshow(dem.array, vmax=8000, vmin=-18000, extent=dem.geoextent)
