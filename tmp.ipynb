# %%
from osgeo import gdal
import matplotlib.pyplot as plt
from pyrsimg import readTiff

# %%
# path = 'data/KH-4/DS1105-2248DA082/DS1105-2248DA082_crop.tif'
# path = 'data/KH-4/DS1105-2248DF076/DS1105-2248DF076_crop_sub8.tif'
path = 'data/KH-4/DS1105-2248DF076/for_small.tif'

# %%
a = gdal.Open(path)
b = a.ReadAsArray()
b.shape
# Out:
# (982, 13520)

# %%
plt.imshow(b)

# %%
path_dem = 'data/dem/SRTMGL1Ellip_kh4.tif'
path_for_map = 'data/KH-4/DS1105-2248DF076/for.map.tif'
path_aft_map = 'data/KH-4/DS1105-2248DA082/aft.map.tif'

# %%
dem = readTiff(path_dem)
for_map = readTiff(path_for_map)
aft_map = readTiff(path_aft_map)

# %%
dem.geoextent
# Out:
# (99.59986111114819, 101.9998611111485, 31.00013888888504, 31.500138888885107)

# %%
for_map.geoextent
# Out:
# (99.59998864139652, 99.8390484413967, 31.270927455992023, 31.316068233104488)

# %%
plt.imshow(dem.array, extent=dem.geoextent)

# %%
plt.imshow(for_map.array, extent=for_map.geoextent, vmax=500, vmin=0)

# %%
plt.imshow(aft_map.array, extent=aft_map.geoextent, vmax=500, vmin=0)

# %%
path_run_dem = 'data/KH-4/stereo_small_mgm/run-DEM.tif'
run_dem = readTiff(path_run_dem)

# %%
plt.imshow(run_dem.array, vmax=10000, vmin=0)

# %%
path_hillshade = 'data/KH-4/stereo_small_mgm/run-reference_hillshade.tif'
hillshade = readTiff(path_hillshade)

# %%
plt.imshow(hillshade.array[:,:,0], vmax=500, vmin=0)

# %%
path_trans = 'data/KH-4/dem/dem-trans_source-DEM.tif'
trans_dem = readTiff(path_trans)
trans_dem.array.shape
# Out:
# (472, 1912)

# %%
plt.imshow(trans_dem.array, vmax=10000, vmin=0, extent=trans_dem.geoextent)

# %%
path_dem = 'data/dem/SRTMGL1Ellip_kh9.tif'
dem = readTiff(path_dem)
dem.array.shape
plt.imshow(dem.array, vmax=10000, vmin=0, extent=dem.geoextent)

# %%
path = 'data/KH-9/D3C1215-100216F011/D3C1215-100216F011_down01.tif'
img = gdal.Open(path).ReadAsArray()
plt.imshow(img)

# %%
path = 'data/KH-9/D3C1215-100216A012/D3C1215-100216A012_down025.tif'
img = gdal.Open(path).ReadAsArray()
plt.imshow(img)

# %%
path = 'data/KH-9/D3C1215-100216A012/D3C1215-100216A012_down025.tif'
img = gdal.Open(path).ReadAsArray()
plt.imshow(img)

# %%
path = 'data/KH-9/D3C1215-100216A012/D3C1215-100216A012_down025.tif'
img = gdal.Open(path).ReadAsArray()
plt.imshow(img)

# %%
fig, ax = plt.subplots(1,1, figsize=(10,4))
# ax.imshow(img[1500:3000,13000:15000])
# ax.imshow(img[1500:3000, 240000:245000])
# ax.imshow(img[5750:6000, 60500:61000])
# ax.imshow(img[5900:6000, 3300:3800])

# %%
path = 'data/KH-9/D3C1215-100216F011/for_down01.tif'
img = gdal.Open(path).ReadAsArray()
print(img.shape)
fig, ax = plt.subplots(1,1, figsize=(10,4))
ax.imshow(img)
# Out:
# (542, 5739)

# %%
path = 'data/KH-9/D3C1215-100216A012/aft_down01.tif'
img = gdal.Open(path).ReadAsArray()
print(img.shape)
fig, ax = plt.subplots(1,1, figsize=(10,4))
ax.imshow(img)
# Out:
# (544, 5737)

# %%
path = 'data/KH-9/init_stereo_d3c1215/run-DEM.tif'
img = gdal.Open(path).ReadAsArray()
fig, ax = plt.subplots(1,1, figsize=(10,4))
ax.imshow(img, vmax=7000, vmin=0)
# Out:
# ERROR 4: data/KH-9/init_stereo_d3c1215/run-DEM.tif: No such file or directory
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 path = 'data/KH-9/init_stereo_d3c1215/run-DEM.tif'
# ----> 2 img = gdal.Open(path).ReadAsArray()
#       3 fig, ax = plt.subplots(1,1, figsize=(10,4))
#       4 ax.imshow(img, vmax=7000, vmin=0)
#
# AttributeError: 'NoneType' object has no attribute 'ReadAsArray'

# %%
path = 'data/KH-9/stereo_extrinsic_d3c1215/run-DEM.tif'
img = gdal.Open(path).ReadAsArray()
fig, ax = plt.subplots(1,1, figsize=(10,4))
ax.imshow(img, vmax=7000, vmin=0)
# Out:
# ERROR 4: data/KH-9/stereo_extrinsic_d3c1215/run-DEM.tif: No such file or directory
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 path = 'data/KH-9/stereo_extrinsic_d3c1215/run-DEM.tif'
# ----> 2 img = gdal.Open(path).ReadAsArray()
#       3 fig, ax = plt.subplots(1,1, figsize=(10,4))
#       4 ax.imshow(img, vmax=7000, vmin=0)
#
# AttributeError: 'NoneType' object has no attribute 'ReadAsArray'

# %%
path = 'data/dem/SRTMGL1Ellip_kh9.tif'
img = gdal.Open(path).ReadAsArray()

# %%
fig, ax = plt.subplots(1,1, figsize=(10,4))
ax.imshow(img)
